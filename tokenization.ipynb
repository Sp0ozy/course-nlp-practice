# %% [markdown]
# # Tokenization Exapmle

# %%
corpus = """Hello! Welcome to the world of programming. Happy coding!
I want to become exper in NLP's
"""

# %%
corpus
# Out:
# "Hello! Welcome to the world of programming. Happy coding!\nI want to become exper in NLP's\n"

# %%
# Tokenization
# Sentece -> Paragraphs
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ilya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents = sent_tokenize(corpus)
documents
# Out:
# ['Hello!',
#  'Welcome to the world of programming.',
#  'Happy coding!',
#  "I want to become exper in NLP's"]

# %%
type(documents)
# Out:
# list

# %%
# Tokrnization
# Sentence -> Words

from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)
words
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'programming',
#  '.',
#  'Happy',
#  'coding',
#  '!',
#  'I',
#  'want',
#  'to',
#  'become',
#  'exper',
#  'in',
#  'NLP',
#  "'s"]

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'programming',
#  '.',
#  'Happy',
#  'coding',
#  '!',
#  'I',
#  'want',
#  'to',
#  'become',
#  'exper',
#  'in',
#  'NLP',
#  "'",
#  's']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'programming.',
#  'Happy',
#  'coding',
#  '!',
#  'I',
#  'want',
#  'to',
#  'become',
#  'exper',
#  'in',
#  "NLP's"]
