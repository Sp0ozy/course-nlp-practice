# %%
# stemming
words = ["run", "runner", "running", "ran", "runs", "eats", "eating", "ate", "eat"]

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

for word in words:
    print(f"{word} -> {stemming.stem(word)}")
# Out:
# run -> run
# runner -> runner
# running -> run
# ran -> ran
# runs -> run
# eats -> eat
# eating -> eat
# ate -> ate
# eat -> eat

# %%
# dissadvantage of stemming is that it can produce non-words, for example:
stemming.stem("happiness")
# Out:
# 'happi'

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer("ing$|s$|e$|able$|ible$", min=4)

reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
for word in words:
    print(f"{word} -> {reg_stemmer.stem(word)}")
# Out:
# run -> run
# runner -> runner
# running -> runn
# ran -> ran
# runs -> run
# eats -> eat
# eating -> eat
# ate -> ate
# eat -> eat

# %%
# Snowball Stemmer
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer("english")

# %%
for word in words:
    print(f"{word} -> {snowball_stemmer.stem(word)}")
# Out:
# run -> run
# runner -> runner
# running -> run
# ran -> ran
# runs -> run
# eats -> eat
# eating -> eat
# ate -> ate
# eat -> eat

# %%
stemming.stem('happiness')
# Out:
# 'happi'

# %%
snowball_stemmer.stem('fairly'), snowball_stemmer.stem('happiness')
# Out:
# ('fair', 'happi')

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Ilya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer.lemmatize("going", pos="v"), lemmatizer.lemmatize("happiness", pos="n")
# Out:
# ('go', 'happiness')
